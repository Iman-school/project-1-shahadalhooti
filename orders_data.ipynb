# %% [markdown]
# # Amazon orders
# to state the raito between mode of payment and the recepit of orders.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('orders_data.csv')
df.head()
# Out:
#               order_no                       order_date       buyer  \
# 0  405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST         Mr.
# 1  404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2  171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3  405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4  402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
#
#       ship_city         ship_state                 sku  \
# 0   CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# 1     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 2     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 3  DEVARAKONDA,          TELANGANA  SKU:  AH-J3AO-R7DN
# 4       MUMBAI,        MAHARASHTRA  SKU:  KL-7WAA-Z82I
#
#                                          description  quantity item_total  \
# 0  100% Leather Elephant Shaped Piggy Coin Bank |...         1    ₹449.00
# ...

# %%
df.isnull()
# Out:
#      order_no  order_date  buyer  ship_city  ship_state    sku  description  \
# 0       False       False  False      False       False  False        False
# 1       False       False  False      False       False  False        False
# 2       False       False  False      False       False  False        False
# 3       False       False  False      False       False  False        False
# 4       False       False  False      False       False  False        False
# ..        ...         ...    ...        ...         ...    ...          ...
# 166     False       False  False      False       False  False        False
# 167     False       False  False      False       False  False        False
# 168     False       False  False      False       False  False        False
# 169     False       False  False      False       False  False        False
# 170     False       False  False      False       False  False        False
#
# ...

# %%
df.isnull().sum()
# Out:
# order_no          0
# order_date        0
# buyer             0
# ship_city         0
# ship_state        0
# sku               0
# description       0
# quantity          0
# item_total       18
# shipping_fee     26
# cod             124
# order_status      0
# dtype: int64

# %%
df['item_total'].isnull().sum()
# Out:
# 18

# %%
df['shipping_fee'].isnull().sum()
# Out:
# 26

# %%
df['cod'].isnull().sum()
# Out:
# 124

# %%
import numpy as np
#we select numeric columns in the dataframe
numeric = df.select_dtypes(include=np.number)
numeric_columns = numeric.columns 
#print the numeric columns
numeric
# Out:
#      quantity
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ..        ...
# 166         3
# 167         1
# 168         1
# 169         1
# 170         1
#
# [171 rows x 1 columns]

# %%
df['quantity'].hist(bins=3)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['shipping_fee'].fillna(df['shipping_fee'].mode()[0], inplace=True)

# imputing with mode as we are considering the item that is sold the most
df['item_total'].fillna(df['item_total'].mode()[0], inplace=True)

# assuming if an order is not cod would mean the mode of payment is online
df['cod'].fillna('online', inplace=True)

# %%
df[['cod', 'order_status', 'item_total']].groupby(['cod', 'order_status']).sum().reset_index()
# Out:
#                 cod        order_status  \
# 0  Cash On Delivery  Delivered to buyer
# 1  Cash On Delivery  Returned to seller
# 2            online  Delivered to buyer
# 3            online  Returned to seller
#
#                                           item_total
# 0  ₹449.00₹399.00₹449.00₹649.00₹399.00₹649.00₹449...
# 1                ₹449.00₹449.00₹449.00₹449.00₹449.00
# 2  ₹449.00₹449.00₹449.00₹1,099.00₹200.00₹399.00₹1...
# 3         ₹449.00₹449.00₹449.00₹449.00₹449.00₹449.00

# %%
sns.factorplot('cod',data=df,hue='order_status',kind='count')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df["cod"].value_counts()
# Out:
# online              124
# Cash On Delivery     47
# Name: cod, dtype: int64

# %%
Cleanup_cod = {"cod":{"online": 0, "Cash On Delivery": 1}}

# %%
df = df.replace(Cleanup_cod)
df.head()
# Out:
#               order_no                       order_date       buyer  \
# 0  405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST         Mr.
# 1  404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2  171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3  405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4  402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
#
#       ship_city         ship_state                 sku  \
# 0   CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# 1     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 2     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 3  DEVARAKONDA,          TELANGANA  SKU:  AH-J3AO-R7DN
# 4       MUMBAI,        MAHARASHTRA  SKU:  KL-7WAA-Z82I
#
#                                          description  quantity item_total  \
# 0  100% Leather Elephant Shaped Piggy Coin Bank |...         1    ₹449.00
# ...

# %%
df["order_status"].value_counts()
# Out:
# Delivered to buyer    160
# Returned to seller     11
# Name: order_status, dtype: int64

# %%
Cleanup_order_status = {"order_status":{"Delivered to buyer": 2, "Returned to seller": 3}}

# %%
df = df.replace(Cleanup_order_status)
df.head()
# Out:
#               order_no                       order_date       buyer  \
# 0  405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST         Mr.
# 1  404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2  171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3  405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4  402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
#
#       ship_city         ship_state                 sku  \
# 0   CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# 1     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 2     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 3  DEVARAKONDA,          TELANGANA  SKU:  AH-J3AO-R7DN
# 4       MUMBAI,        MAHARASHTRA  SKU:  KL-7WAA-Z82I
#
#                                          description  quantity item_total  \
# 0  100% Leather Elephant Shaped Piggy Coin Bank |...         1    ₹449.00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

orders_data= pd.read_csv("orders_data.csv")
orders_data
# Out:
#                 order_no                       order_date       buyer  \
# 0    405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST         Mr.
# 1    404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2    171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3    405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4    402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
# ..                   ...                              ...         ...
# 166  171-2829978-1258758  Mon, 13 Dec, 2021, 11:30 am IST      Shahin
# 167  402-3045457-5360311   Wed, 1 Dec, 2021, 12:18 pm IST  Sharmistha
# 168  408-2260162-8323567    Thu, 9 Dec, 2021, 6:55 pm IST    shashank
# 169  403-5664951-8941100  Wed, 23 Feb, 2022, 12:43 am IST      Jayeta
# 170  402-4845680-8041921   Sun, 26 Dec, 2021, 6:21 pm IST       Varun
#
#         ship_city         ship_state                 sku  \
# 0     CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# ...

# %%
df["cod"].value_counts()
# Out:
# 0    124
# 1     47
# Name: cod, dtype: int64

# %%
Cleanup_cod = {"cod":{"online": 0, "Cash On Delivery": 1}}

# %%
df = df.replace(Cleanup_cod)
df.head()
# Out:
#               order_no                       order_date       buyer  \
# 0  405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST         Mr.
# 1  404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2  171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3  405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4  402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
#
#       ship_city         ship_state                 sku  \
# 0   CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# 1     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 2     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 3  DEVARAKONDA,          TELANGANA  SKU:  AH-J3AO-R7DN
# 4       MUMBAI,        MAHARASHTRA  SKU:  KL-7WAA-Z82I
#
#                                          description  quantity item_total  \
# 0  100% Leather Elephant Shaped Piggy Coin Bank |...         1    ₹449.00
# ...

# %%
df["order_status"].value_counts()
# Out:
# 2    160
# 3     11
# Name: order_status, dtype: int64

# %%
Cleanup_order_status = {"order_status":{"Delivered to buyer": 2, "Returned to seller": 3}}

# %%
df = df.replace(Cleanup_order_status)
df.head()
# Out:
#               order_no                       order_date       buyer  \
# 0  405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST         Mr.
# 1  404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2  171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3  405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4  402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
#
#       ship_city         ship_state                 sku  \
# 0   CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# 1     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 2     PASIGHAT,  ARUNACHAL PRADESH  SKU:  DN-0WDX-VYOT
# 3  DEVARAKONDA,          TELANGANA  SKU:  AH-J3AO-R7DN
# 4       MUMBAI,        MAHARASHTRA  SKU:  KL-7WAA-Z82I
#
#                                          description  quantity item_total  \
# 0  100% Leather Elephant Shaped Piggy Coin Bank |...         1    ₹449.00
# ...
